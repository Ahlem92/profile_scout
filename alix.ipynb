# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pip install openpyxl
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.0/250.0 kB 4.9 MB/s eta 0:00:0000:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Projet profile_scout - Notebook perso

# %% [markdown]
# ## Traitement des données

# %% [markdown]
# ### Exploration des données

# %%
file = "/mnt/c/Users/macgr/Downloads/Career Mode player datasets - FIFA 15-22.xlsx"
fifa_df = pd.read_excel(file, sheet_name='FIFA 22')

# %%
fifa_df
# Out:
#        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 1          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2           9014  https://sofifa.com/player/9014/arjen-robben/15...
# 3          41236  https://sofifa.com/player/41236/zlatan-ibrahim...
# 4         167495  https://sofifa.com/player/167495/manuel-neuer/...
# ...          ...                                                ...
# 16150     220806  https://sofifa.com/player/220806/ellis-redman/...
# 16151     225509  https://sofifa.com/player/225509/aaron-collins...
# 16152     201197  https://sofifa.com/player/201197/paul-tisdale/...
# 16153     217591  https://sofifa.com/player/217591/piotr-zemlo/1...
# 16154     222947  https://sofifa.com/player/222947/tom-davies/15...
#
#               short_name                            long_name  \
# 0               L. Messi       Lionel Andrés Messi Cuccittini
# ...

# %%
file = "/mnt/c/Users/macgr/Downloads/Search results.xlsx"
besoccer_df = pd.read_excel(file)

# %%
besoccer_df
# Out:
#                     Player             Team      Position   Age  Market value  \
# 0               Rúben Dias  Manchester City      RCB, LCB  25.0      75000000
# 1                 R. James          Chelsea  RWB, RB, RCB  23.0      70000000
# 2               M. de Ligt   Bayern München      LCB, RCB  23.0      70000000
# 3               Marquinhos              PSG  RCB, CB, LCB  28.0      70000000
# 4                W. Fofana          Chelsea           RCB  21.0      65000000
# ...                    ...              ...           ...   ...           ...
# 18195        A. Abdel Aziz           Smouha            LB  29.0             0
# 18196  Mohamed El Maghraby           Smouha       LB, LCB  21.0             0
# 18197       Karim Al Tayeb            ENPPI        CF, LW  24.0             0
# 18198         Mostafa Adel            ENPPI   LWB, LW, LB  23.0             0
# 18199             A. Sylla           Smouha       CF, AMF  23.0             0
#
# ...

# %%
fifa_df = fifa_df.filter(fifa_df.columns[:96])

# %%
plt.plot(fifa_df['pace'])
